# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_inc = pd.read_csv('../data/data/dph_od_incident_counts.csv')
df_res = pd.read_csv('../data/data/dph_od_resident_counts.csv')

# %%
df_inc.head()
# Out:
#   ZIPCODE X2014Q1 X2014Q2 X2014Q3 X2014Q4 X2015Q1 X2015Q2 X2015Q3 X2015Q4  \
# 0   19102       0       0       0       0       0       0      <6       0
# 1   19103      <6       0      <6       0       0       0       0       0
# 2   19104      <6      <6      <6       6       6       6      <6      <6
# 3   19106       0       0      <6      <6      <6       0       0      <6
# 4   19107      <6      <6      <6      <6      <6      <6       0      <6
#
#   X2016Q1  ... X2016Q3 X2016Q4 X2017Q1 X2017Q2 X2017Q3 X2017Q4 X2018Q1  \
# 0      <6  ...       0      <6      <6       0      <6      <6       0
# 1       0  ...      <6      <6      <6      <6      <6       0      <6
# 2      <6  ...      <6       6      <6       6       9       8      <6
# 3      <6  ...      <6      <6      <6      <6      <6      <6      <6
# 4       6  ...      <6      <6      <6      <6      <6      <6      <6
#
#   X2018Q2 X2018Q3 X2018Q4
# 0      <6      <6       0
# 1      <6      <6      <6
# ...

# %%
print(df_inc)
