# %%
# !pip install pandas
# Out:
# ...
#      |████████████████████████████████| 10.1MB 2.6MB/s
# ...
#      |████████████████████████████████| 20.1MB 1.1MB/s
# ...
#      |████████████████████████████████| 512kB 744kB/s
# ...

# %%
# !ls ../../data/
# Out:
# data.zip			hf_physician_locator.csv
# dph_dash_ems_naloxone_age.csv	hf_samsha_programs.csv
# dph_dash_ems_naloxone_sex.csv	hf_samsha_providers.csv
# dph_dash_ems_naloxone_zip.csv	pp_refill_events.csv
# dph_dash_n_ed_transfers.csv	pp_refill_zipcode_metrics.csv
# dph_dash_n_naloxone_admins.csv	pp_sep_site_exchanges.csv
# dph_od_incident_counts.csv	pp_sep_site_participants.csv
# dph_od_resident_counts.csv	psp_overdose_events.csv

# %%
import pandas as pd

data_prefix = '../../data/'

pd.read_csv(f'{data_prefix}psp_overdose_events.csv')
# Out:
#        Incident ID Incident Date Incident Time       Day Incident County Name  \
# 0                1      1/4/2018       0:42:00  Thursday             Delaware
# 1                1      1/4/2018       0:42:00  Thursday             Delaware
# 2                1      1/4/2018       0:42:00  Thursday             Delaware
# 3                1      1/4/2018       0:42:00  Thursday             Delaware
# 4               26     1/26/2018       9:14:00    Friday              Chester
# ...            ...           ...           ...       ...                  ...
# 15116        14310     1/11/2020       0:00:00  Saturday                Adams
# 15117        14311     1/13/2020       8:32:00    Monday              Cambria
# 15118        14312     1/14/2020      15:13:00   Tuesday            Lancaster
# 15119        14313    12/14/2019      21:30:00  Saturday           Montgomery
# 15120        14313    12/14/2019      21:30:00  Saturday           Montgomery
#
# ...

# %%
pd.read_csv(f'{data_prefix}dph_dash_ems_naloxone_zip.csv')
# Out:
#     Pickup.Zip.Code  Numebr.of.Records
# 0             19116                187
# 1             19154                281
# 2             19115                149
# 3             19114                233
# 4             19111                301
# 5             19152                232
# 6             19136                444
# 7             19149                356
# 8             19135                566
# 9             19137                176
# 10            19124               1243
# 11            19120                333
# 12            19126                 66
# 13            19141                257
# 14            19138                113
# 15            19150                 46
# 16            19119                 74
# 17            19144                315
# 18            19140                702
# 19            19129                 80
# 20            19134               4674
# 21            19118                 14
# 22            19128                165
# ...
